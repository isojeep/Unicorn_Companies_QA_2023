# %% [markdown]
# ## Connection of Libraries

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd

#Importing necessary visualisation tools
import seaborn as sns
import matplotlib.pyplot as plt

#Load and read dataset file
unicorn_data = pd.read_csv(r'D:\Downloads\EXCEL ASSIGNMENT AND PROJECTS\Python Analytics\DATASETS\Unicorn_Companies.csv')
unicorn_data
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %% [markdown]
# ## Data Inspection and Manipulation

# %%
#Shape
unicorn_data.shape
# Out:
# (1074, 10)

# %%
#Columns
unicorn_data.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Industry', 'City', 'Country',
#        'Continent', 'Year Founded', 'Funding', 'Select Investors'],
#       dtype='object')

# %%
#Data types
unicorn_data.dtypes
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country             object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
#Info
unicorn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
#Identify missing values using isnull().sum()
unicorn_data.isnull().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                16
# Country              0
# Continent            0
# Year Founded         0
# Funding              0
# Select Investors     1
# dtype: int64

# %%
#Visualising missing values on magma_r
plt.figure(figsize = (10,6))
plt.title('Visualise missing values')
sns.heatmap(unicorn_data.isnull(), cbar = True, cmap = 'magma_r')
plt.show()

# %%
#Statistical descriptive analysis of the numerical features
unicorn_data.describe().astype('int')
# Out:
#        Year Founded
# count          1074
# mean           2012
# std               5
# min            1919
# 25%            2011
# 50%            2014
# 75%            2016
# max            2021

# %%
#Data Cleaning - City Column
cities = unicorn_data['City'].value_counts().sort_values(ascending= False)
cities
# Out:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
#                 ...
# Barcelona          1
# Sherman Oaks       1
# Boise              1
# Tsuruoka           1
# Milpitas           1
# Name: City, Length: 256, dtype: int64

# %%
unicorn_data['City'].dtype
# Out:
# dtype('O')

# %%
unicorn_data['City'].fillna('Unknown', inplace=True)
unicorn_data['Valuation'].fillna('Unknown', inplace=True)

# %%
unicorn_data.isna().sum()
# Out:
# Company             0
# Valuation           0
# Date Joined         0
# Industry            0
# City                0
# Country             0
# Continent           0
# Year Founded        0
# Funding             0
# Select Investors    0
# dtype: int64

# %%
#Data Cleaning - Select Investors Column
s_investors = unicorn_data['Select Investors'].value_counts().sort_values(ascending= False)
s_investors
# Out:
# Sequoia Capital                                                                          3
# Undisclosed                                                                              2
# Speedinvest, Valar Ventures, Uniqa Ventures                                              2
# Two Sigma Ventures, Flint Capital, Commerce Ventures                                     2
# Tiger Global Management, Sequoia Capital India, Ribbit Capital                           2
#                                                                                         ..
# 58.com, Tencent Holdings                                                                 1
# Xingwang Investment Management, China Capital Investment Group, Matrix Partners China    1
# IAG Capital Partners, Augmentum Fintech, Northzone Ventures                              1
# Northzone Ventures, Maveron, Johnson & Johnson Innovation                                1
# ...

# %%
unicorn_data['Select Investors'].dtype
# Out:
# dtype('O')

# %%
unicorn_data['Select Investors'].fillna('Unknown', inplace=True)

# %%
unicorn_data.isna().sum()
# Out:
# Company             0
# Valuation           0
# Date Joined         0
# Industry            0
# City                0
# Country             0
# Continent           0
# Year Founded        0
# Funding             0
# Select Investors    0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analyisis: Relationship, Insights and Visualisation
#
# #### Univariate, Bivariate & Multivariate Analysis

# %%
#Cities by Unicorn Companies - Top 5
cities_top = unicorn_data['City'].value_counts().sort_values(ascending= False)
cities_top = unicorn_data.groupby(['City']).size().reset_index(name='counts').sort_values(by=['counts'], ascending=False).head(5)
cities_top
# Out:
#               City  counts
# 200  San Francisco     152
# 162       New York     103
# 14         Beijing      63
# 215       Shanghai      44
# 131         London      34

# %%
sns.set(style="whitegrid")
ax = sns.barplot(x="counts", y="City", data=cities_top)
plt.title('Top 5 Cities with the Most Unicorn Companies')
plt.xlabel('Number of Unicorn Companies')
plt.ylabel('City')

for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=10)

plt.show()

# %%
#Countries by Unicorn Companies - Top 5
countries_top = unicorn_data['Country'].value_counts().sort_values(ascending= False)
countries_top = unicorn_data.groupby(['Country']).size().reset_index(name='counts').sort_values(by=['counts'], ascending=False).head(5)

#Visualisation of Contries by Unicorn Companies
sns.set(style="whitegrid")
ax = sns.barplot(x="counts", y="Country", data=countries_top)
plt.title('Top 5 Country with the Most Unicorn Companies')
plt.xlabel('Number of Unicorn Companies')
plt.ylabel('Country')

for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=10)

plt.show()

# %%
#Companies by Valuation - Top 5
companies_top = unicorn_data.sort_values(by='Valuation', ascending=False).head(5)
companies_top
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          Fintech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded  Funding  \
# 0        Beijing          China           Asia          2012        8
# 1      Hawthorne  United States  North America          2002        7
# 2       Shenzhen          China           Asia          2008        2
# 3  San Francisco  United States  North America          2010        2
# 4      Stockholm         Sweden         Europe          2005        4
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
#Visualisation - Companies by Valuation
sns.set(style="whitegrid")
plt.figure(figsize=(10,5))
ax = sns.barplot(x="Company", y="Valuation", data=companies_top)
ax.set_title('Top 5 Companies by Valuation')
ax.set_xlabel('Company')
ax.set_ylabel('Valuation (in billions of dollars)')
for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=10)

plt.show()

# %%
#Companies by funding - Top 5
unicorn_data['Funding'] = unicorn_data['Funding'].astype(str).replace('Unknown', '0').str.replace('$','').str.replace('B','').str.replace('M','').fillna(0).astype(int)
companies_top = unicorn_data.sort_values(by='Valuation', ascending=False).head(5)
companies_top = companies_top.sort_values(by='Funding', ascending=True)

plt.barh(companies_top['Company'], companies_top['Funding'], color=['green', 'red', 'purple', 'orange', 'blue'])
plt.title('Top 5 Companies by Funding')
plt.xlabel('Funding (in billions of dollars)')

plt.ylabel('Company')

plt.show()
# Out:
# C:\Users\THOBANI\AppData\Local\Temp\ipykernel_21804\3009765546.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   unicorn_data['Funding'] = unicorn_data['Funding'].astype(str).replace('Unknown', '0').str.replace('$','').str.replace('B','').str.replace('M','').fillna(0).astype(int)

# %%
unicorn_data['Funding'] = unicorn_data['Funding'].astype(str).replace('Unknown', '0').str.replace('$','').str.replace('B','').str.replace('M','').fillna(0).astype(int)

companies_top = unicorn_data.sort_values(by='Valuation', ascending=False).head(5)

plt.pie(companies_top['Funding'], labels=companies_top['Company'], autopct='%1.1f%%')
plt.title('Top 5 Companies by Funding')
plt.show()
# Out:
# C:\Users\THOBANI\AppData\Local\Temp\ipykernel_21804\2060065794.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   unicorn_data['Funding'] = unicorn_data['Funding'].astype(str).replace('Unknown', '0').str.replace('$','').str.replace('B','').str.replace('M','').fillna(0).astype(int)

# %%
#Years in Unicorn - Top 5
# Convert the 'Date Joined' column to datetime
companies_top['Date Joined'] = pd.to_datetime(companies_top['Date Joined'])

# Calculate the number of years it took for each company to join the unicorn club
companies_top['Years to Unicorn'] = (companies_top['Date Joined'] - companies_top['Year Founded']).dt.days / 365

companies_top
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          Fintech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City        Country      Continent Year Founded  Funding  \
# 0        Beijing          China           Asia   2012-01-01        8
# 1      Hawthorne  United States  North America   2002-01-01        7
# 2       Shenzhen          China           Asia   2008-01-01        2
# 3  San Francisco  United States  North America   2010-01-01        2
# 4      Stockholm         Sweden         Europe   2005-01-01        4
#
#                                     Select Investors  Years to Unicorn
# ...

# %%
# Visualisation of Years in Unicorn - Top 5 Line Chart
# Create a line chart
sns.set(style="whitegrid")
plt.figure(figsize=(10,5))
ax = sns.lineplot(data=companies_top, x='Company', y='Years to Unicorn')
ax.set_title('Years to Unicorn for Top 5 Companies')
ax.set_xlabel('Company')
ax.set_ylabel('Years to Unicorn')

plt.show()

# %%
# Visualisation - Years in Unicorn - Top 5 Bar Chart
# Create a bar chart
sns.set(style="whitegrid")
plt.figure(figsize=(10,5))
ax = sns.barplot(data=companies_top, x='Company', y='Years to Unicorn')
ax.set_title('Years to Unicorn for Top 5 Companies')
ax.set_xlabel('Company')
ax.set_ylabel('Years to Unicorn')

for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=10, fmt='%.1f')

plt.show()

# %%
# Split the values in the 'Select Investors' column by comma
investors = unicorn_data['Select Investors'].str.split(', ')

# Explode the resulting Series to create a row for each investor
investors = investors.explode()

# Count the occurrences of each investor
s_investors = investors.value_counts().sort_values(ascending=False)

# Display the resulting Series
s_investors
# Out:
# Accel                         60
# Tiger Global Management       53
# Andreessen Horowitz           53
# Sequoia Capital China         48
# Insight Partners              47
#                               ..
# Stellaris Venture Partners     1
# Inflexion Private Equity       1
# Trifecta Capital Advisors      1
# Leonardo DiCaprio              1
# Causeway Media Partners        1
# Name: Select Investors, Length: 1259, dtype: int64

# %%
# Select the first five investors with the highest count
top_investors = s_investors.head()

# Define a list of colors for the bars
colors = ['red', 'orange', 'yellow', 'green', 'blue']

# Create a bar chart of the top investors with different colors for the bars
ax = top_investors.plot(kind='bar', color=colors)

# Add labels to the bars
for i in ax.containers:
    ax.bar_label(i)

# Add labels and title
plt.xlabel('Select Investors')
plt.ylabel('Number of Investments')
plt.title('Top 5 Select Investors Internationally')
plt.xticks(rotation=80)
# Show the plot
plt.show()

# %%
# Select the first five investors with the highest count
top_investors = s_investors.head()

# Create a pie chart of the top investors
top_investors.plot(kind='pie', autopct='%1.1f%%')

# Add title
plt.title('Top 5 Unicorn Company Investors Internationally')
plt.ylabel('')

# Show the plot
plt.show()
